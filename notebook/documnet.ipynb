# %% [markdown]
# #### <code>Data Ingetion </code>

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={"source": "generated", "author": "langchain"},
)

# %%
sample_text ={
  "../data/sample1.txt": '''Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead, these systems learn from data and improve their performance over time through experience.''',
  
  "../data/sample2.txt": '''Natural Language Processing (NLP) is a branch of artificial intelligence that focuses on the interaction between computers and humans through natural language. The ultimate objective of NLP is to enable computers to understand, interpret, and generate human language in a way that is valuable.''',
}

for file_path, content in sample_text.items():
  with open(file_path, 'w', encoding='utf-8') as f:
    f.write(content)

# %%
# TextLoaders
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders.text import TextLoader
loader = TextLoader("../data/sample1.txt")
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/sample1.txt'}, page_content='Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead, these systems learn from data and improve their performance over time through experience.')]

# %%
# DirecotoryLoader
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders.directory import DirectoryLoader

loader = DirectoryLoader(
  "../data", # Directory path
  glob="*.txt", # Optional: pattern to match specific files
  loader_cls=TextLoader  # We can user any loader class here ,ex: PDFLoader,CSVLoader etc
  )
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\sample1.txt'}, page_content='Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead, these systems learn from data and improve their performance over time through experience.'),
#  Document(metadata={'source': '..\\data\\sample2.txt'}, page_content='Natural Language Processing (NLP) is a branch of artificial intelligence that focuses on the interaction between computers and humans through natural language. The ultimate objective of NLP is to enable computers to understand, interpret, and generate human language in a way that is valuable.')]

# %%
# PDFLoader
from langchain_community.document_loaders import PyPDFLoader,PyMuPDFLoader
# loader1 = PyPDFLoader("../data/Resume_DataScience.pdf")
# documents1 = loader1.load() 
# documents1

loader2 = PyMuPDFLoader("../data/Resume_DataScience.pdf",)
documents2 = loader2.load()
documents2
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-11-09T05:15:55+00:00', 'source': '../data/Resume_DataScience.pdf', 'file_path': '../data/Resume_DataScience.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Bengaluru, India | mohsinaliabidali320@gmail.com | 9327900855 PROFILE Entry-Level Data Scientist proficient in Python, SQL, NumPy, Pandas, and Scikit-learn. Skilled in exploratory data analysis (EDA) and machine learning techniques including', 'author': 'Mohsin Ali', 'subject': '', 'keywords': 'DAGuRgPk6hQ,BAFlxON1WvE,0', 'moddate': '2025-11-09T05:15:55+00:00', 'trapped': '', 'modDate': "D:20251109051555+00'00'", 'creationDate': "D:20251109051555+00'00'", 'page': 0}, page_content='MOHSINALI AGHARIYA\nBengaluru, India | mohsinaliabidali320@gmail.com | 9327900855\nPROFILE\nMotivated and detail-oriented entry-level Data Scientist with a strong academic\nfoundation in Python, SQL, and machine learning. Proficient in data analysis, model\nbuilding
# ...
